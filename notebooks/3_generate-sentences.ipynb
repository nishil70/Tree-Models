# %% [markdown]
# # Text Generation and Predition using Amazon Fine Food reviews.

# %%
import pandas as pd
import numpy as np
import warnings
import MarkovModel
import pickle
warnings.filterwarnings('ignore')

# %%
df = pd.read_pickle(r'C:\Users\nishi\source\repos\HiddenMarkovModel\archives\my_df.pkl',compression='gzip')

# %%
df = df[['tokenized_Reviews']]

# %%
df.head()
# Out:
#                                    tokenized_Reviews
# 0  [I, have, bought, several, of, the, Vitality, ...
# 1  [Product, arrived, labeled, as, Jumbo, Salted,...
# 2  [This, is, a, confection, that, has, been, aro...
# 3  [If, you, are, looking, for, the, secret, ingr...
# 4  [Great, taffy, at, a, great, price, ., There, ...

# %%
dictionary, end_words = MarkovModel.create_dictionary(df['tokenized_Reviews'])

# %%
dictionary.head()
# Out:
#       lead   follow      freq
# 0        I     have  128440.0
# 1     have   bought    2512.0
# 2   bought  several     434.0
# 3  several       of    1272.0
# 4       of      the  150764.0

# %%
probability_matrix = MarkovModel.transition_probability_matrix(dictionary)

# %%
probability_matrix.head()
# Out:
# follow       !         #        $   %   &   '        ''  '90s  'Africafe  \
# lead
# !       0.2991       NaN      NaN NaN NaN NaN  0.006335   NaN        NaN
# #          NaN       NaN      NaN NaN NaN NaN       NaN   NaN        NaN
# $          NaN       NaN  0.06534 NaN NaN NaN       NaN   NaN        NaN
# %          NaN       NaN      NaN NaN NaN NaN       NaN   NaN        NaN
# &          NaN  0.021178      NaN NaN NaN NaN       NaN   NaN        NaN
#
# follow  'Choice ...   }   ~  ~1  ~6-hour  ~The  ~half  ~~   §   ½  Ît
# lead            ...
# !           NaN ... NaN NaN NaN      NaN   NaN    NaN NaN NaN NaN NaN
# #           NaN ... NaN NaN NaN      NaN   NaN    NaN NaN NaN NaN NaN
# $           NaN ... NaN NaN NaN      NaN   NaN    NaN NaN NaN NaN NaN
# %           NaN ... NaN NaN NaN      NaN   NaN    NaN NaN NaN NaN NaN
# &           NaN ... NaN NaN NaN      NaN   NaN    NaN NaN NaN NaN NaN
#
# [5 rows x 15317 columns]

# %%
# Generate a sentence
sentence = MarkovModel.make_a_sentence('Bought', probability_matrix, end_words)
print(sentence)
# Out:
# Bought this brand again . What a month I believe that the one of the other brands , not be a spoon of beans , not bitter after a few

# %% [markdown]
# # Summary
# - generated sentence are sequence of words constructed from transition probability matrix
# - generated sentences are not necessarily meant to make sense, they are based on 2nd order markov property, so two words together would likely make sense but not the whole sentence
